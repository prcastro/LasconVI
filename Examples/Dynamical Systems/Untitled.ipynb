# %%
# %matplotlib inline
import pandas
import numpy as np
import matplotlib.pyplot as plt

# %%
diagram = np.loadtxt('diagram.dat', usecols=[0, 1, 2])
trajectory = pandas.read_csv("trajectory.dat", sep=" ")
plt.plot(diagram[:,0], diagram[:,1], diagram[:,0], diagram[:,2])
plt.plot(trajectory["o"], trajectory["v"])

# %%
# Out:
# 3
